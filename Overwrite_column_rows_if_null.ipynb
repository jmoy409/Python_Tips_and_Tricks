# %%
#Case when: if Role_y and Points_x exists, fill in value
#https://stackoverflow.com/questions/74737791/using-python-pandas-can-i-replace-values-of-one-column-in-a-df-based-on-another
#overwrite column y with column ya given column y is null. if not null, do not overwrite
final_df["col_y"] = final_df["col_y"].where(final_df["col_ya"].notna(), final_df["col_ya"])
final_df["col_x"] = final_df["col_x"].where(final_df["col_x"].notna(), final_df["col_xa"])
